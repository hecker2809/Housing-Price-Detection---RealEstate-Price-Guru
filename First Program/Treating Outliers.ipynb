# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

raw_data = pd.read_csv("1. Regression - Module - (Housing Prices).csv")
raw_data
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    221900.0               3
# 1      6414100192    14 December 2017    538000.0               3
# 2      5631500400    15 February 2016    180000.0               2
# 3      2487200875    14 December 2017    604000.0               4
# 4      1954400510    15 February 2016    510000.0               3
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    360000.0               3
# 21609  6600060120    15 February 2016    400000.0               4
# 21610  1523300141        14 June 2017    402101.0               2
# 21611   291310100     15 January 2016    400000.0               3
# 21612  1523300157     14 October 2017    325000.0               2
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0                 1.00               1180.0              5650.0           1.0
# ...

# %%
plt.scatter(x = raw_data['ID'], y = raw_data['Sale Price'])

# %%
import seaborn as sns
sns.boxplot(x = raw_data['Sale Price'])
# Out:
# <Axes: xlabel='Sale Price'>

# %%
q1 = raw_data['Sale Price'].quantile(.25)
q3 = raw_data['Sale Price'].quantile(.75)

iqr = q3 - q1

lower_limit = q1-(1.5*iqr)
upper_limit = q3+(1.5*iqr)

#BUT (lower_limit < min) value So,
#lower_limit = min(raw_data['Sale Price'])

print(lower_limit, upper_limit)
# Out:
# -162625.0 1129575.0

# %%
def limit_imputer(value):
    if value > upper_limit:
        return upper_limit
    if value < lower_limit:
        return lower_limit
    else:
        return value

# %%
raw_data['Sale Price'] = raw_data['Sale Price'].apply(limit_imputer)

# %%
raw_data['Sale Price'].describe()
# Out:
# count    2.160900e+04
# mean     5.116186e+05
# std      2.500620e+05
# min      7.500000e+04
# 25%      3.219500e+05
# 50%      4.500000e+05
# 75%      6.450000e+05
# max      1.129575e+06
# Name: Sale Price, dtype: float64
